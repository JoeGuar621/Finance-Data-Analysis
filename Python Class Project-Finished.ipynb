# %% [markdown]
# # The Impact of COVID-19 on the S&P 500

# %% [markdown]
# ## Research Questions
#
# ### 1. How did the COVID-19-induced 2020 stock market crash affect S&P 500 open/close prices?
# ### 2. How did trade volume change in the wake of the crash?
# ### 3. What was the impact of the U.S.' stock market crash on another country's stock market?

# %% [markdown]
# # Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('SPX.csv')
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 1     2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 2     2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 3     2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 4     2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
# ...          ...          ...          ...          ...          ...
# 1001  2023-12-22  4753.919922  4772.939941  4736.770020  4754.629883
# 1002  2023-12-26  4758.859863  4784.720215  4758.450195  4774.750000
# 1003  2023-12-27  4773.450195  4785.390137  4768.899902  4781.580078
# 1004  2023-12-28  4786.439941  4793.299805  4780.979980  4783.350098
# 1005  2023-12-29  4782.879883  4788.430176  4751.990234  4769.830078
#
#         Adj Close      Volume
# 0     3257.850098  3459930000
# 1     3234.850098  3484700000
# 2     3246.280029  3702460000
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.index.names = ['Time Point']
df.columns.names = ['Parameters']
df['Date'] = pd.to_datetime(df['Date'])

# %%
df2 = df[df['Date'].dt.year == 2020]
df2.head()
# Out:
# Parameters       Date         Open         High          Low        Close  \
# Time Point
# 0          2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098
# 1          2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098
# 2          2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029
# 3          2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932
# 4          2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049
#
# Parameters    Adj Close      Volume
# Time Point
# 0           3257.850098  3459930000
# 1           3234.850098  3484700000
# 2           3246.280029  3702460000
# 3           3237.179932  3435910000
# 4           3253.050049  3726840000

# %% [markdown]
# # EDA - Plotting

# %% [markdown]
# ## Stock Price and Trade Volume Plots

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Date'], df['Open'], label='Open Price', color='blue')
plt.plot(df['Date'], df['Close'], label='Close Price', color='red')


plt.title('S&P 500 Open/Close Prices 2020-2023')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df2['Date'], df2['Open'], label='Open Price', color='blue')
plt.plot(df2['Date'], df2['Close'], label='Close Price', color='red')

# Adding titles and labels
plt.title('S&P 500 Open/Close Prices in 2020')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
spx_2019 = pd.read_csv('SPX-2019.csv')
spx_2019['Date'] = pd.to_datetime(spx_2019['Date'])
spx_2019.index.names = ['Time Point']
spx_2019.columns.names = ['Parameters']
plt.figure(figsize=(14, 7))
plt.plot(spx_2019['Date'], spx_2019['Open'], label='Open Price', color='blue')
plt.plot(spx_2019['Date'], spx_2019['Close'], label='Close', color='red')


plt.title('S&P 500 Open/Close Prices in 2019')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
df_march = df2[(df2['Date'] >= '2020-03-01') & (df2['Date'] <= '2020-03-31')]
df_march.index.names = ['Time Point']
df_march.columns.names = ['Parameters']
df_march

plt.figure(figsize=(14, 7))
plt.plot(df_march['Date'], df_march['Open'], label='Open Price', color='blue')
plt.plot(df_march['Date'], df_march['Close'], label='Close Price', color='red')


plt.title('S&P 500 Open/Close Prices in March of 2020')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df_march['Date'], df_march['Volume'], label='Volume', color='blue')


plt.title('S&P 500 Volume in March of 2020')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
df_april = df2[(df2['Date'] >= '2020-04-01') & (df2['Date'] <= '2020-04-30')]
df_april.index.names = ['Time Point']
df_april.columns.names = ['Parameters']
df_april

plt.figure(figsize=(14, 7))
plt.plot(df_april['Date'], df_april['Open'], label='Open Price', color='blue')
plt.plot(df_april['Date'], df_april['Close'], label='Close Price', color='red')


plt.title('S&P 500 Open/Close Prices in April of 2020')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
plt.figure(figsize=(14, 7))
plt.plot(df_april['Date'], df_april['Volume'], label='Volume', color='blue')


plt.title('S&P 500 Volume in April of 2020')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()


plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# %%
#US economy in 2020, impact on Japanese economy

# %% [markdown]
# # Import Nikkei (Japanese stock exchange) Data

# %%
nikkei = pd.read_csv('N225.csv')
nikkei['Date'] = pd.to_datetime(nikkei['Date'])

nikkei
# Out:
#           Date          Open          High           Low         Close  \
# 0   2020-01-06  23319.759766  23365.359375  23148.529297  23204.859375
# 1   2020-01-07  23320.119141  23577.439453  23299.919922  23575.720703
# 2   2020-01-08  23217.490234  23303.210938  22951.179688  23204.759766
# 3   2020-01-09  23530.289063  23767.089844  23506.150391  23739.869141
# 4   2020-01-10  23813.279297  23903.289063  23761.080078  23850.570313
# ..         ...           ...           ...           ...           ...
# 237 2020-12-24  26635.109375  26764.529297  26605.259766  26668.349609
# 238 2020-12-25  26708.099609  26716.609375  26638.279297  26656.609375
# 239 2020-12-28  26691.289063  26854.029297  26664.599609  26854.029297
# 240 2020-12-29  26936.380859  27602.519531  26921.140625  27568.150391
# 241 2020-12-30  27559.099609  27572.570313  27338.560547  27444.169922
#
#         Adj Close    Volume
# 0    23204.859375  72800000
# 1    23575.720703  64300000
# ...

# %% [markdown]
# # Clean Nikkei Data

# %%
#Convert Yen to USD
nikkei['Open'] = nikkei['Open']*0.0064
nikkei['Close'] = nikkei['Close']*0.0064
nikkei['High'] = nikkei['High']*0.0064
nikkei['Low'] = nikkei['Low']*0.0064
nikkei['Adj Close'] = nikkei['Adj Close']*0.0064


nikkei
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-01-06  149.246463  149.538300  148.150588  148.511100  148.511100
# 1   2020-01-07  149.248763  150.895612  149.119488  150.884612  150.884612
# 2   2020-01-08  148.591937  149.140550  146.887550  148.510463  148.510463
# 3   2020-01-09  150.593850  152.109375  150.439363  151.935163  151.935163
# 4   2020-01-10  152.404988  152.981050  152.070912  152.643650  152.643650
# ..         ...         ...         ...         ...         ...         ...
# 237 2020-12-24  170.464700  171.292988  170.273663  170.677437  170.677437
# 238 2020-12-25  170.931837  170.986300  170.484988  170.602300  170.602300
# 239 2020-12-28  170.824250  171.865788  170.653437  171.865788  171.865788
# 240 2020-12-29  172.392837  176.656125  172.295300  176.436163  176.436163
# 241 2020-12-30  176.378237  176.464450  174.966788  175.642688  175.642688
#
#        Volume
# 0    72800000
# 1    64300000
# 2    79400000
# ...

# %% [markdown]
# # Merge Nikkei and S&P 500 Data

# %%
nikkei_march = nikkei[(nikkei['Date'] >= '2020-03-01') & (nikkei['Date'] <= '2020-03-31')]


merged2 = pd.merge(df_march, nikkei_march, on='Date', how='outer', suffixes=('_spx','_nkk')).dropna()
merged2.head()
# Out:
#         Date     Open_spx     High_spx      Low_spx    Close_spx  \
# 0 2020-03-02  2974.280029  3090.959961  2945.189941  3090.229980
# 1 2020-03-03  3096.459961  3136.719971  2976.629883  3003.370117
# 2 2020-03-04  3045.750000  3130.969971  3034.379883  3130.120117
# 3 2020-03-05  3075.699951  3083.040039  2999.830078  3023.939941
# 4 2020-03-06  2954.199951  2985.929932  2901.540039  2972.370117
#
#    Adj Close_spx  Volume_spx    Open_nkk    High_nkk     Low_nkk   Close_nkk  \
# 0    3090.229980  6381330000  133.438650  138.195900  133.339450  136.602112
# 1    3003.370117  6376510000  138.572737  139.006588  134.929475  134.929475
# 2    3130.120117  5073020000  133.742075  135.973950  133.517125  135.040388
# 3    3023.939941  5579290000  136.959163  136.959163  135.812863  136.506363
# 4    2972.370117  6555240000  134.462725  134.791675  131.929025  132.798400
#
#    Adj Close_nkk   Volume_nkk
# 0     136.602112  123700000.0
# 1     134.929475  105300000.0
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model
# Train the model
regression_model2 = linear_model.LinearRegression()
regression_model2.fit(X = pd.DataFrame(merged2["Close_spx"]), 
                     y = merged2["Close_nkk"])

# Check trained model y-intercept
print(regression_model2.intercept_)

# Check trained model coefficients
print(regression_model2.coef_)
# Out:
# 28.513787348225975
# [0.03481526]

# %%
regression_model2.score(X = pd.DataFrame(merged2["Close_spx"]), 
                       y = merged2["Close_nkk"])
# Out:
# 0.7741201348492306

# %%
#77% of variance in Nikkei explained by US Market, though coefficient is small.

# %%
train_prediction2 = regression_model2.predict(X = pd.DataFrame(merged2["Close_spx"]))

# Actual - prediction = residuals
residuals = merged2["Close_nkk"] - train_prediction2

residuals.describe()
# Out:
# count    2.100000e+01
# mean     2.706829e-15
# std      4.892778e+00
# min     -1.133993e+01
# 25%     -2.449342e+00
# 50%      8.007775e-01
# 75%      2.182529e+00
# max      1.039739e+01
# Name: Close_nkk, dtype: float64

# %% [markdown]
# # Conclusions
#
# ### A number of conclusions can be made about the U.S. stock market based on this analysis:
#
# #### 1. First, the market is resilient. Although a steep crash occurred in March of 2020, the market began to climb again (and trading volume began to increase) shortly after that. Second, although the 2020 market, in the aggregate, was valued lower than that of the 2019 market, the month-by-month growth was visually similar to the 2019 market, which may speak to the market’s ability to course correct.
#
# #### 2. This also speaks to the market’s susceptibility to contextual factors and changes in public policy and healthcare. The market’s periods of growth in late 2020/early-mid 2021, for example, coincided with the release of the COVID-19 vaccine and the removal of some social distancing measures and restrictions.
#
# #### 3. Second, the market has a strong impact on the economies of other nations. When used in a regression analysis to predict the Tokyo Stock Exchange (Nikkei), the results showed that much of the variance in Nikkei data can be explained by changes in the S&P 500.
#
# #### 4. However, the fact that this analysis was a univariate linear regression rather than a multivariate regression should be seen as a limitation. Before making more concrete claims, a multivariate regression should be performed, although the present analysis was limited in its data sources.
